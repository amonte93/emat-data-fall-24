# %% [markdown]
# # Austin Monte
# # Data in Hand

# %% [markdown]
# ## I have gathered the data of 13 games played, and recorded in-game statistics of each character played in all 13 games. The game records several different stats, including the following:
#
#
# ### Batting Average
# ### Hits
# ### RBIs
# ### Homeruns
# ### Special Hits (the game has a feature where you can spend a resource for special hits & pitches, Mario throws/hits a fireball, Yoshi/Birdo turn the ball into an egg that bounces around, etc.)
# ### Stolen Bases
# ### Pitching Erorr (ERA)
# ### Strikeouts (K)
# ### Big Plays (the game determines this as jumping/sliding catches, using abilities when fielding, double plays, any defensive play thats bigger than a standard out)
# ### MVP

# %% [markdown]
# ## I averaged out the data for each character across all the games, and want to find out who is the best in each category to determine who is the overall best character. I plan to visualize this using graphs, and comparing data between characters. Attached is a screen shot of the data I will be using.

# %% [markdown]
# ![Screenshot 2024-11-27 at 12.40.50 PM.png](attachment:f2b406d7-b0d3-40ec-897f-7fb59108ef38.png)

# %% [markdown]
# ### My main concern is missing ERA data, as not every character pitches, but putting 0 would be problematic since a 0 ERA means a perfect pitching game (no hits allowed)
